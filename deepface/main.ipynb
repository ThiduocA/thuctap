# %%
from deepface import DeepFace
# from deepface.modules.modeling import build_model
import os
import cv2
import matplotlib.pyplot as plt

# %%
current_path = os.getcwd()
img1_path = os.path.join(current_path, 'data' ,'img1.jpg')
img2_path = os.path.join(current_path, 'data' ,'img2.jpg')
# print(img1_path)
# print(img2_path)

# %%
img1 = cv2.imread(img1_path)
img2 = cv2.imread(img2_path)

# %%
plt.imshow(img1[:, :, ::-1])
plt.show()

plt.imshow(img2[:, :, ::-1])
plt.show()

# %%
result = DeepFace.verify(img1_path, img2_path)
# tf_keras = 2.17.0
# keras = 3.5.0
# tensorflow = 2.17.0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 result = DeepFace.verify(img1_path, img2_path)
#       2 # tf_keras = 2.17.0
#       3 # keras = 3.5.0
#       4 # tensorflow = 2.17.0
#
# File d:\tts\deepface\.venv\Lib\site-packages\deepface\DeepFace.py:150, in verify(img1_path, img2_path, model_name, detector_backend, distance_metric, enforce_detection, align, expand_percentage, normalization, silent, threshold, anti_spoofing)
#      70 def verify(
#      71     img1_path: Union[str, np.ndarray, List[float]],
#      72     img2_path: Union[str, np.ndarray, List[float]],
#    (...)     82     anti_spoofing: bool = False,
#      83 ) -> Dict[str, Any]:
#      84     """
#      85     Verify if an image pair represents the same person or different persons.
#      86     Args:
#    (...)    147         - 'time' (float): Time taken for the verification process in seconds.
#     148     """
# --> 150     return verification.verify(
#     151         img1_path=img1_path,
#     152         img2_path=img2_path,
#     153         model_name=model_name,
#     154         detector_backend=detector_backend,
#     155         distance_metric=distance_metric,
#     156         enforce_detection=enforce_detection,
#     157         align=align,
#     158         expand_percentage=expand_percentage,
#     159         normalization=normalization,
#     160         silent=silent,
#     161         threshold=threshold,
#     162         anti_spoofing=anti_spoofing,
#     163     )
#
# File d:\tts\deepface\.venv\Lib\site-packages\deepface\modules\verification.py:103, in verify(img1_path, img2_path, model_name, detector_backend, distance_metric, enforce_detection, align, expand_percentage, normalization, silent, threshold, anti_spoofing)
#      30 """
#      31 Verify if an image pair represents the same person or different persons.
#      32
#    (...)     98     - 'time' (float): Time taken for the verification process in seconds.
#      99 """
#     101 tic = time.time()
# --> 103 model: FacialRecognition = modeling.build_model(
#     104     task="facial_recognition", model_name=model_name
#     105 )
#     106 dims = model.output_shape
#     108 no_facial_area = {
#     109     "x": None,
#     110     "y": None,
#    (...)    114     "right_eye": None,
#     115 }
#
# AttributeError: module 'deepface.modules.modeling' has no attribute 'build_model'
